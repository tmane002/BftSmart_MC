# %%
import pylab as pl

# %%
import numpy as np

# %%
n_clusters = np.array([1,2,4])
# times = np.array([37203758548, 28362218781, 22138146062])

# %%
# throughputs = 1000 * 1e9/times
throughputs = np.array([6628-509,10426-807,21726-1615])
# latencies = np.array([])

# %%
# n_replicas = np.array([16,8,4])
# throughputs2 = 1000 * 1e9/times

# %%
pl.plot(n_clusters, throughputs/50, '-*')
pl.title('Throughputs with total number of nodes = 16')
pl.xlabel('Number of Clusters')
pl.ylabel('Throughput(TPS)')
pl.xticks([1,2,4])
pl.savefig('Throughputs.png', dpi = 150)
pl.show()
pl.clf()

# %%
pl.plot(n_replicas, throughputs2, '-*')
pl.title('Throughputs with total number of nodes = 16')
pl.xlabel('Number of Replicas per cluster')
pl.ylabel('Throughput')
pl.xticks([4,8,16])
pl.show()
pl.clf()
